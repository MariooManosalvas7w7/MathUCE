# %%
def tabla_de_verdad(p, q):
    print(f"{'p':^8} | {'q':^8} | {'p and q':^12} | {'p or q':^10} | {'not p':^10}")
    print("-" * 50)
    for p_val in [True, False]:
        for q_val in [True, False]:
            p_and_q = p_val and q_val
            p_or_q = p_val or q_val
            not_p = not p_val
            print(f"{str(p_val):^8} | {str(q_val):^8} | {str(p_and_q):^12} | {str(p_or_q):^10} | {str(not_p):^10}")

# Ejemplo de uso
print("Tabla de Verdad para p y q:")
tabla_de_verdad(True, False)
# Ejemplo de cuantificador universal (∀)
conjunto = [2, 4, 6, 8, 10]
todos_pares = all(x % 2 == 0 for x in conjunto)
print(f"¿Todos los elementos en {conjunto} son pares?: {todos_pares}")

# Ejemplo de cuantificador existencial (∃)
hay_negativo = any(x < 0 for x in conjunto)
print(f"¿Hay algún número negativo en {conjunto}?: {hay_negativo}")
def negacion_proposicion(p):
    print(f"{'p':^10} | {'not p':^10}")
    print("-" * 25)
    print(f"{str(p):^10} | {str(not p):^10}")

# Ejemplo de uso
print("Negación de la proposición 'p es par':")
negacion_proposicion(True)
import ipywidgets as widgets
from IPython.display import display

def tabla_interactiva(p, q):
    tabla_de_verdad(p, q)

# Crear widgets para los valores de p y q
p_widget = widgets.ToggleButtons(options=[True, False], description='p:')
q_widget = widgets.ToggleButtons(options=[True, False], description='q:')

# Mostrar los widgets interactivos
display(widgets.interactive(tabla_interactiva, p=p_widget, q=q_widget))
def negacion_proposicion(p):
    print(f"{'Proposición P':^20} | {'Negación de P':^20}")
    print("-" * 45)
    print(f"{p:^20} | {'No ' + p:^20}")

# Ejemplo
print("Ejemplo de Negación de Proposición:")
negacion_proposicion("Todo elemento de A es par")
def ejercicio_negacion(p):
    print(f"Proposición P: {p}")
    print(f"Negación de P: No {p}")

# Ejemplo
print("Ejemplo de Negación de Proposición Compuesta:")
ejercicio_negacion("Para todo n natural, existe un k natural tal que k > n")
def despertador_y_rutina():
    print("Ejemplo de Algoritmo No Computacional:")
    print("1. Despertarse con alarma")
    print("2. Bañarse")
    print("3. Desayunar")
    print("4. Vestirse")
    print("5. Ir a trabajar")


# Búsqueda lineal
def buscar_lineal(numero_a_adivinar, limite_inferior, limite_superior):
    intentos = 0
    for numero in range(limite_inferior, limite_superior + 1):
        intentos += 1
        if numero == numero_a_adivinar:
            return numero, intentos
    return None, intentos

# Simulación de adivinanza con búsqueda lineal
numero_a_adivinar = 88
limite_inferior = 1
limite_superior = 100
numero_encontrado_lineal, pasos_lineal = buscar_lineal(numero_a_adivinar, limite_inferior, limite_superior)


def buscar_planeta(candidatos):
    # Ejemplo de búsqueda binaria para encontrar el planeta correcto
    limite_inferior = 0
    limite_superior = len(candidatos) - 1
    preguntas = 0

    while limite_inferior <= limite_superior:
        preguntas += 1
        medio = (limite_inferior + limite_superior) // 2



        if respuesta == "sí":
            return candidatos[medio], preguntas
        elif respuesta == "no":
            siguiente_pregunta = input("¿El planeta favorito tiene un aspecto azulado? (sí/no): ").lower().strip()
            if siguiente_pregunta == "sí":
                return "Neptuno", preguntas + 1
            else:
                return "Saturno", preguntas + 1
        else:
            print("Respuesta no válida. Por favor responde 'sí' o 'no'.")

    return None, preguntas

# Lista de candidatos a planetas favoritos
candidatos = ["Mercurio", "Venus", "Tierra", "Marte", "Júpiter", "Saturno", "Urano", "Neptuno"]



# Ejemplos de cálculo de bits para diferentes tipos de información
pin = 10000
pin_bits = pin.bit_length()
print(f"Para un PIN de 10,000 posibles combinaciones, se necesitan aproximadamente {pin_bits} bits para codificarlo.")

caracteres = 100
caracteres_bits = caracteres.bit_length()
print(f"Para un mensaje de 100 caracteres, se necesitan aproximadamente {caracteres_bits} bits para codificarlo.")

# Ejemplo práctico con imágenes
pixeles = 28800
bits_por_pixel = 3
imagen_bits = pixeles * bits_por_pixel
print(f"Para una imagen pequeña de 28,800 píxeles con 8 colores por píxel, se necesitan aproximadamente {imagen_bits} bits para codificarla.")
# Ejemplo de proposición matemática con cuantificadores
def ejemplo_proposicion(naturales):
    # Para todo n en los naturales, existe un k en los naturales tal que k <= n
    for n in naturales:
        encontrado = False
        for k in naturales:
            if k <= n:
                encontrado = True
                break
        if not encontrado:
            return False
    return True

# Conjunto de números naturales
naturales = [1, 2, 3, 4, 5]

# Verificar la proposición con los números naturales definidos
resultado = ejemplo_proposicion(naturales)
print(f"La proposición es {resultado}")
# Negación de la proposición anterior
def negacion_proposicion(naturales):
    # Existe un n en los naturales tal que para todo k en los naturales, k > n
    for n in naturales:
        encontrado = True
        for k in naturales:
            if not (k > n):
                encontrado = False
                break
        if encontrado:
            return True
    return False

# Verificar la negación de la proposición con los números naturales definidos
resultado_negacion = negacion_proposicion(naturales)
print(f"La negación de la proposición es {resultado_negacion}")
# Ejemplo práctico: encontrar el mínimo en un conjunto de números naturales
def encontrar_minimo(naturales):
    minimo = naturales[0]
    for num in naturales:
        if num < minimo:
            minimo = num
    return minimo

# Conjunto de números naturales para encontrar el mínimo
naturales_ejemplo = [3, 8, 1, 5, 2]

# Encontrar el mínimo
minimo_encontrado = encontrar_minimo(naturales_ejemplo)
print(f"El mínimo en el conjunto es {minimo_encontrado}")
# Cuaderno de Google Colab: Introducción a la Lógica Matemática y Teoría de Conjuntos

# Ejemplo 1: Interpretación de cuantificadores
def ejemplo_proposicion(naturales):
    # Para todo n en los naturales, existe un k en los naturales tal que k <= n
    for n in naturales:
        encontrado = False
        for k in naturales:
            if k <= n:
                encontrado = True
                break
        if not encontrado:
            return False
    return True

# Ejemplo 2: Negación de proposiciones
def negacion_proposicion(naturales):
    # Existe un n en los naturales tal que para todo k en los naturales, k > n
    for n in naturales:
        encontrado = True
        for k in naturales:
            if not (k > n):
                encontrado = False
                break
        if encontrado:
            return True
    return False

# Ejemplo 3: Operaciones con números naturales
def suma_numeros(a, b):
    return a + b

# Conjunto de números naturales para ejemplos
naturales = [1, 2, 3, 4, 5]

# Verificación de los ejemplos
print(f"Ejemplo 1: La proposición es {ejemplo_proposicion(naturales)}")
print(f"Ejemplo 2: La negación de la proposición es {negacion_proposicion(naturales)}")
print(f"Ejemplo 3: Suma de 3 y 4 es {suma_numeros(3, 4)}")

# Conclusiones y próximos pasos
print("\nEste cuaderno proporciona una introducción práctica y teórica a la lógica matemática, cuantificadores, negación de proposiciones y operaciones básicas con números naturales.")
print("Explora y modifica los ejemplos para profundizar en estos conceptos y su aplicación en la resolución de problemas matemáticos.")
# Cuaderno de Google Colab: Introducción a Conjuntos Numéricos y Problemas Algebraicos

# Ejemplo 1: Suma de números enteros
def suma_enteros(a, b):
    return a + b

# Ejemplo 2: Problema aritmético básico
def problema_aritmetico(a, b):
    return a + b

# Ejemplo 3: Problema algebraico con cambio de perspectiva
def problema_algebraico(a, b):
    return a * b

# Ejemplo 4: Simetrización con respecto a la suma (números enteros)
def simetrizacion_suma(n):
    return -n

# Ejemplo 5: Simetrización con respecto a la multiplicación (números racionales)
def simetrizacion_multiplicacion(x):
    return 1 / x

# Conjunto de números para ejemplos
naturales = [1, 2, 3, 4, 5]
enteros = [-3, -2, -1, 0, 1, 2, 3]
racionales = [1/2, 2/3, -3/4, 5/1]

# Verificación de los ejemplos
print(f"Ejemplo 1: La suma de 3 y 4 es {suma_enteros(3, 4)}")
print(f"Ejemplo 2: Problema aritmético con 20 y 30 resulta en {problema_aritmetico(20, 30)}")
print(f"Ejemplo 3: Problema algebraico de 20 asociado a 50 ovejas es {problema_algebraico(20, 50)}")
print(f"Ejemplo 4: Simetrización de -3 con respecto a la suma es {simetrizacion_suma(-3)}")
print(f"Ejemplo 5: Simetrización de 2/3 con respecto a la multiplicación es {simetrizacion_multiplicacion(2/3)}")

# Conclusiones y próximos pasos
print("\nEste cuaderno proporciona una introducción práctica a los conjuntos numéricos y problemas algebraicos básicos.")
print("Explora y modifica los ejemplos para entender cómo diferentes conjuntos numéricos permiten resolver distintos tipos de problemas.")
# Cuaderno de Google Colab: Introducción a Conjuntos Numéricos y Números Complejos

# Ejemplo 1: Ejemplo de número irracional (raíz cuadrada de 2)
import math

raiz_cuadrada_de_2 = math.sqrt(2)
print(f"La raíz cuadrada de 2 es un número irracional: {raiz_cuadrada_de_2}")

# Ejemplo 2: Problema algebraico con ecuación cuadrática
def resolver_ecuacion_cuadratica(a, b, c):
    discriminante = b**2 - 4*a*c
    if discriminante < 0:
        return "No tiene solución real (solución compleja)"
    elif discriminante == 0:
        x = -b / (2*a)
        return f"Tiene una solución real única: x = {x}"
    else:
        x1 = (-b + math.sqrt(discriminante)) / (2*a)
        x2 = (-b - math.sqrt(discriminante)) / (2*a)
        return f"Tiene dos soluciones reales: x1 = {x1}, x2 = {x2}"

# Verificación del ejemplo de ecuación cuadrática
print("\nEjemplo 2: Resolver la ecuación cuadrática x^2 + 1 = 0")
print(resolver_ecuacion_cuadratica(1, 0, 1))

# Conclusiones y próximos pasos
print("\nEste cuaderno proporciona una introducción a los conjuntos numéricos, desde los racionales hasta los complejos.")
print("Explora cómo los problemas matemáticos conducen a la necesidad de expandir nuestros conjuntos numéricos para resolver diferentes tipos de problemas.")
# Out:
# Tabla de Verdad para p y q:
#    p     |    q     |   p and q    |   p or q   |   not p
# --------------------------------------------------
#   True   |   True   |     True     |    True    |   False
#   True   |  False   |    False     |    True    |   False
#  False   |   True   |    False     |    True    |    True
#  False   |  False   |    False     |   False    |    True
# ¿Todos los elementos en [2, 4, 6, 8, 10] son pares?: True
# ¿Hay algún número negativo en [2, 4, 6, 8, 10]?: False
# Negación de la proposición 'p es par':
#     p      |   not p
# -------------------------
#    True    |   False
# interactive(children=(ToggleButtons(description='p:', options=(True, False), value=True), ToggleButtons(descri…
# Ejemplo de Negación de Proposición:
#    Proposición P     |    Negación de P
# ---------------------------------------------
# Todo elemento de A es par | No Todo elemento de A es par
# Ejemplo de Negación de Proposición Compuesta:
# ...
