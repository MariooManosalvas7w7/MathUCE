# %%
# Clase 4: Conceptos Básicos de Funciones de Utilidad

### Función de Utilidad con Dos Bienes


import sympy as sp

# Definición de la función de utilidad
X, Y = sp.symbols('X Y')
utilidad = sp.sqrt(X * Y)

# Resolviendo el problema
nivel_utilidad = 10
solucion = sp.solve(utilidad - nivel_utilidad, Y)

print(f"Para una utilidad de {nivel_utilidad}, las combinaciones de bienes son:")
for sol in solucion:
    print(f"X = {sol.evalf()}, Y = {nivel_utilidad**2 / sol.evalf()}")

import matplotlib.pyplot as plt
import numpy as np

# Definición de la función f(x) = x^2
def f(x):
    return x ** 2

# Generación de datos para graficar
x = np.linspace(-3, 3, 400)
y = f(x)

# Gráfica de la función f(x)
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = x^2')
plt.title('Gráfica de la función f(x) = x^2')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Conceptos Básicos de Funciones: Inyectividad y Sobreyectividad

# Conceptos Básicos de Funciones: Inyectividad y Sobreyectividad

## Introducción



## Funciones y Definiciones
# Ejemplo 1: Función de Utilidad con Nivel de Utilidad Diferente

import sympy as sp

# Definición de la función de utilidad
X, Y = sp.symbols('X Y')
utilidad = sp.sqrt(X * Y)

# Resolviendo el problema con un nivel de utilidad diferente
nivel_utilidad = 15
solucion = sp.solve(utilidad - nivel_utilidad, Y)

print(f"Para una utilidad de {nivel_utilidad}, las combinaciones de bienes son:")
for sol in solucion:
    print(f"X = {sol.evalf()}, Y = {nivel_utilidad**2 / sol.evalf()}")

# Gráfica de la función cuadrática
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return x ** 2

x = np.linspace(-5, 5, 400)
y = f(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = x^2')
plt.title('Gráfica de la función f(x) = x^2')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Ejemplo 2: Función de Utilidad con Diferentes Formas Funcionales

import sympy as sp

# Definición de la función de utilidad diferente
X, Y = sp.symbols('X Y')
utilidad = X**0.5 + Y**0.5

# Resolviendo el problema
nivel_utilidad = 20
solucion = sp.solve(utilidad - nivel_utilidad, Y)

print(f"Para una utilidad de {nivel_utilidad}, las combinaciones de bienes son:")
for sol in solucion:
    print(f"X = {sol.evalf()}, Y = {(nivel_utilidad - sol**0.5)**2}")

# Gráfica de la función cuadrática
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return x ** 3

x = np.linspace(-3, 3, 400)
y = f(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = x^3')
plt.title('Gráfica de la función f(x) = x^3')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Ejemplo 3: Función Cuadrática Diferente

import matplotlib.pyplot as plt
import numpy as np

# Definición de la función f(x) = x^3 - 2x
def f(x):
    return x ** 3 - 2 * x

# Generación de datos para graficar
x = np.linspace(-3, 3, 400)
y = f(x)

# Gráfica de la función f(x)
plt.figure(figsize=(8, 6))
# Out:
# Para una utilidad de 10, las combinaciones de bienes son:
# X = 100.0/X, Y = 1.0*X
# Para una utilidad de 15, las combinaciones de bienes son:
# X = 225.0/X, Y = 1.0*X
# Para una utilidad de 20, las combinaciones de bienes son:
# X = 400.0*(0.05*X**0.5 - 1.0)**2, Y = 400.0*(1 - ((0.05*X**0.5 - 1)**2)**0.5)**2
