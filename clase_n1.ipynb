# %%
# Bienvenidos a la introducción a las matemáticas para economía y ciencias sociales

# Inicio del curso
print("Buenos días a todos, espero que estén bien.")
print("Bienvenidos a todos los presentes y a los que nos siguen virtualmente.")

# Introducción al curso
print("\nEste curso tiene como objetivo cambiar la forma de introducir las matemáticas en economía y ciencias sociales.")
print("No nos centraremos solo en las herramientas matemáticas, sino en comprender profundamente los conceptos y su lenguaje.")

# Contenido del curso
print("\nEn la primera parte, que va desde hoy hasta el 11 de Julio, nos enfocaremos en lógica proposicional y teoría de conjuntos.")
print("En agosto nos concentraremos en temas más avanzados.")

# Lógica proposicional
print("\nEmpezaremos con los conectores lógicos como 'y', 'o', 'no', 'si...entonces' y 'si y solo si'.")
print("Una proposición es una frase que puede ser verdadera o falsa, denotada generalmente con letras como p, q, r.")

# Lenguaje matemático
print("\nUtilizaremos cuantificadores como 'para todo' (∀) y 'existe' (∃) para formalizar nuestras ideas.")
print("El lenguaje matemático ayuda a evitar ambigüedades y contradicciones.")

# Conjuntos
print("\nUn conjunto es una colección de elementos. Los elementos pueden ser números, personas, formas geométricas, etc.")
print("Denotaremos conjuntos con letras mayúsculas (A, B) y elementos con letras minúsculas (x, y).")

# Ejemplo de demostración
print("\nPara demostrar, por ejemplo, la implicación lógica entre dos proposiciones, usaremos símbolos en lugar de lenguaje natural.")
print("Esto nos ayuda a ser más precisos y eficientes en nuestros argumentos.")

# Finalización
print("\nEspero que tengan una buena experiencia de aprendizaje hasta el 11 de Julio.")
print("Vamos a comenzar directamente con la clase. ¡Saquen sus apuntes y empecemos!")

# Bienvenidos al curso sobre teoría de conjuntos y operaciones básicas

# Introducción
print("Bienvenidos al curso. Hoy hablaremos sobre la teoría de conjuntos y sus operaciones.")

# Símbolos y gramática matemática
print("\nPara señalar la pertenencia de un elemento a un conjunto, usamos el símbolo ∈.")
print("Para indicar que un elemento no pertenece, usamos la e tachada (∉).")

# Relaciones entre conjuntos
print("\nCuando trabajamos con conjuntos, es útil referirse al conjunto mayor, Omega.")
print("Siendo a y b subconjuntos de Omega, notamos a ⊆ Omega y b ⊆ Omega.")

# Definición de subconjunto
print("\nUn conjunto a ⊆ Omega significa que todos los elementos de a son elementos de Omega.")

# Uso de cuantificadores
print("\nUtilizamos cuantificadores como 'para todo' (∀) y 'existe' (∃).")
print("Por ejemplo, ∀x ∈ a implica que cada x en a también está en Omega.")

# Operaciones entre conjuntos
print("\nLas operaciones básicas entre conjuntos incluyen:")
print("- Intersección (∩): elementos comunes en a y b.")
print("- Unión (∪): elementos en a, b o ambos.")
print("- Complemento ('): elementos no en a.")

# Ejemplos de operaciones entre conjuntos
print("\nEjemplo: Si a, b ⊆ Omega, entonces:")
print("- a ∩ b significa elementos que están tanto en a como en b.")
print("- a ∪ b significa elementos que están en a, en b, o en ambos.")
print("- a' significa elementos en Omega que no están en a.")

# Generalización y notación compacta
print("\nPara generalizar las operaciones, usamos subíndices:")
print("Si tenemos a1, a2, ..., an ⊆ Omega, usamos subíndices para ser más concisos.")

# Conclusión
print("\nEl lenguaje matemático nos permite ser precisos y eficientes en nuestras descripciones.")
print("Espero que este curso les ayude a entender mejor la teoría de conjuntos y sus aplicaciones.")
# Resumen sobre teoría de conjuntos y operaciones básicas

# Introducción
print("Bienvenidos al curso sobre teoría de conjuntos y operaciones básicas.")

# Símbolos y gramática matemática
print("\nEn matemáticas, distinguimos entre pertenencia (∈) y subconjunto (⊆).")
print("Para ser precisos, pertenencia indica que un elemento es parte de un conjunto, mientras que subconjunto indica que un conjunto es contenido dentro de otro.")

# Generalización con índices
print("\nPara generalizar conjuntos con índices, utilizamos notaciones como a₁, a₂, ..., aₙ, donde n es un número natural.")
print("Esto nos permite manejar una familia finita de subconjuntos de manera más compacta.")

# Compactando la notación
print("\nPara expresar la idea de 'para todo i desde 1 hasta n, aᵢ pertenece a A', podemos usar:")
print("∀i ∈ {1, 2, ..., n} : aᵢ ⊆ Omega.")

def tabla_de_verdad(p, q):
    print(f"{'p':^8} | {'q':^8} | {'p and q':^12} | {'p or q':^10} | {'p -> q':^10}")
    print("-" * 50)
    for p_val in [True, False]:
        for q_val in [True, False]:
            p_and_q = p_val and q_val
            p_or_q = p_val or q_val
            p_implies_q = (not p_val) or q_val
            print(f"{str(p_val):^8} | {str(q_val):^8} | {str(p_and_q):^12} | {str(p_or_q):^10} | {str(p_implies_q):^10}")

# Ejemplo de uso
print("Tabla de Verdad para p y q:")
tabla_de_verdad(True, False)
# Out:
# Buenos días a todos, espero que estén bien.
# Bienvenidos a todos los presentes y a los que nos siguen virtualmente.
#
# Este curso tiene como objetivo cambiar la forma de introducir las matemáticas en economía y ciencias sociales.
# No nos centraremos solo en las herramientas matemáticas, sino en comprender profundamente los conceptos y su lenguaje.
#
# En la primera parte, que va desde hoy hasta el 11 de Julio, nos enfocaremos en lógica proposicional y teoría de conjuntos.
# En agosto nos concentraremos en temas más avanzados.
#
# Empezaremos con los conectores lógicos como 'y', 'o', 'no', 'si...entonces' y 'si y solo si'.
# Una proposición es una frase que puede ser verdadera o falsa, denotada generalmente con letras como p, q, r.
#
# Utilizaremos cuantificadores como 'para todo' (∀) y 'existe' (∃) para formalizar nuestras ideas.
# El lenguaje matemático ayuda a evitar ambigüedades y contradicciones.
#
# ...
